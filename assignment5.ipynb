# %% [markdown]
# # task 1

# %%
class BankAccount:
    def __init__(self, balance=0):
        self.balance = balance
    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited {amount}. New balance: {self.balance}")
        else:
            print("Invalid amount")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds")
        elif amount > 0:
            self.balance -= amount
            print(f"Withdrew {amount}. New balance: {self.balance}")
        else:
            print("Invalid amount")

    def check_balance(self):
        print(f"Current balance: {self.balance}")

account = BankAccount(100)
account.deposit(50)
account.withdraw(30)
account.check_balance()
# Out:
# Deposited 50. New balance: 150
# Withdrew 30. New balance: 120
# Current balance: 120

# %% [markdown]
# # task 2

# %%
class Calculator:

    def __init__(self):
        """Initializes the calculator class."""
        pass

    def add(self, a, b):
        """Add two numbers."""
        return a + b

    def subtract(self, a, b):
        """Subtract two numbers."""
        return a - b

    def multiply(self, a, b):
        """Multiply two numbers."""
        return a * b

    def divide(self, a, b):
        """Divide two numbers."""
        if b != 0:
            return a / b
        else:
            return "Error! Division by zero."

    def calculator(self):
        """Main calculator logic to get user input and perform operations."""
        print("Welcome to the calculator!")
        print("Choose an operation:")
        print("1: Add")
        print("2: Subtract")
        print("3: Multiply")
        print("4: Divide")

        choice = input(
            "Enter the number of the operation you want to perform (1/2/3/4): "
        )

        if choice in ["1", "2", "3", "4"]:
            try:
                num1 = float(input("Enter the first number: "))
                num2 = float(input("Enter the second number: "))
            except ValueError:
                print("Invalid input! Please enter numbers only.")
                return

            if choice == "1":
                print(f"{num1} + {num2} = {self.add(num1, num2)}")
            elif choice == "2":
                print(f"{num1} - {num2} = {self.subtract(num1, num2)}")
            elif choice == "3":
                print(f"{num1} * {num2} = {self.multiply(num1, num2)}")
            elif choice == "4":
                result = self.divide(num1, num2)
                if isinstance(result, str):
                    print(result)
                else:
                    print(f"{num1} / {num2} = {result}")
        else:
            print("Invalid choice! Please select a valid operation (1/2/3/4).")


calc = Calculator()
calc.calculator()
# Out:
# Welcome to the calculator!
# Choose an operation:
# 1: Add
# 2: Subtract
# 3: Multiply
# 4: Divide
# 5.0 / 5.0 = 1.0

# %% [markdown]
# # task 3

# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def ms(self):
        pass

    def describe(self):
        print("Animal")
class Dog(Animal):

    def ms(self):
        return "haw haw"

class Cat(Animal):
    def ms(self):
        return "Meow meow"
class Cow(Animal):

    def ms(self):
        return "Moo moo"
dog = Dog()
dog.describe()
print(f"Dog sound: {dog.ms()}")

cat = Cat()
cat.describe()
print(f"Cat sound: {cat.ms()}")

cow = Cow()
cow.describe()
print(f"Cow sound: {cow.ms()}")
# Out:
# Animal
# Dog sound: haw haw
# Animal
# Cat sound: Meow meow
# Animal
# Cow sound: Moo moo

# %% [markdown]
# # task4

# %%
class TextFileReader:
    def __init__(self, file_path):
        self.file_path = file_path
        self.content = ""
    def rf(self):
        with open(self.file_path, "r") as f:
            self.content = f.read()
    def cl(self):
        return len(self.content.splitlines())
    def cw(self):
        return len(self.content.split())
    def cc(self):
        return len(self.content)
    def display_content(self):
        print(self.content)

# %% [markdown]
# # task 5

# %%
class WordCounter:
    def count_word_frequency(self, words_list):
        freq = {}
        for word in words_list:
            if word in freq:
                freq[word] += 1
            else:
                freq[word] = 1
        return freq
counter = WordCounter()
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
print(counter.count_word_frequency(words))
# Out:
# {'Welcome': 1, 'Ali': 4, 'Hi': 2, 'No': 3}

# %%
# طريقه تانيه 
class WordCounter:
    def __init__(self, words_list):
        self.words_list = words_list
    def count_word_frequency(self):
        freq = {}
        for word in self.words_list:
            if word in freq:
                freq[word] += 1
            else:
                freq[word] = 1
        return freq
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
counter = WordCounter(words)
print(counter.count_word_frequency())
# Out:
# {'Welcome': 1, 'Ali': 4, 'Hi': 2, 'No': 3}

# %% [markdown]
# # task 6

# %%
def read_txt_file(file_path):
    try:
        with open(file_path, "r") as file:
            return file.readlines()
    except FileNotFoundError:
        return []

class UserExtractor:
    def __init__(self, file_path):
        self.file_path = file_path
        self.usernames = {}
    def extract_usernames(self):
        lines = read_txt_file(self.file_path)
        for line in lines:
            line = line.strip()
            if ":" in line:
                parts = line.split(":")
                self.usernames[parts[0]] = parts[1]
        return self.usernames
